# %% [markdown]
# ### imports and setup

# %%
# # google colab setup (comment out this cell if running locally)
# from google.colab import drive
# drive.mount('/content/drive', force_remount=True)
# %cd "/content/drive/My Drive/_research ML AQ/lorenz 96 gnn" # so we can access pre-generated lorenz data
# !pip3 install spektral

# %%
# ipython extension to autoreload imported modules so that any changes will be up to date before running code in this nb
# %load_ext autoreload 
# %autoreload 2

# Load the TensorBoard notebook extension
# %load_ext tensorboard
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
# import packages
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from lorenz import lorenzDataset, DEFAULT_TIME_RESOLUTION
from plotters import plot_data
from tuning import make_train_GCN, make_train_GCN3, plot_model_results
from models import NaiveConstant, NaiveZero

from spektral.data import MixedLoader

from datetime import datetime
# Out:
# 2023-02-14 11:07:15.537129: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# check that GPU is set up
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
    print('no GPU device found')
else:
    print('found GPU at: {}'.format(device_name))
print('num GPUs available:', len(tf.config.list_physical_devices("GPU")))
# Out:
# no GPU device found
# num GPUs available: 0
# 2023-02-14 11:07:21.944450: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### prepare data

# %%
# only uncomment each line if testing a non-default parameter
dataset = lorenzDataset(
    n_samples=10_000,
    # input_steps=2 * DEFAULT_TIME_RESOLUTION,  # 2 days
    # output_delay=1 * DEFAULT_TIME_RESOLUTION,  # 1 day
    # output_steps=1,
    min_buffer=-3 * DEFAULT_TIME_RESOLUTION,
    # rand_buffer=False,
    # K=36,
    # F=8,
    # c=10,
    # b=10,
    # h=1,
    # coupled=True,
    # time_resolution=DEFAULT_TIME_RESOLUTION,
    # seed=42
)
# Out:
# reading Lorenz data from stored file

# %%
train = dataset[:int(0.7 * dataset.n_graphs)]
val = dataset[int(0.7 * dataset.n_graphs):int(0.9 * dataset.n_graphs)]
test = dataset[int(0.9 * dataset.n_graphs):]

# %%
train_loader = MixedLoader(dataset=train, batch_size=32, shuffle=False)
val_loader = MixedLoader(dataset=val, batch_size=32, shuffle=False)

# %%
# TODO: store normalized train/val/test data

# normalize data
start = datetime.now()
X1_mean, X1_std, X2_mean, X2_std = train.get_mean_std()
finish_get_means = datetime.now()
print('time to get means:', finish_get_means - start)

train.normalize(X1_mean, X1_std, X2_mean, X2_std)
val.normalize(X1_mean, X1_std, X2_mean, X2_std)
test.normalize(X1_mean, X1_std, X2_mean, X2_std)
finish_normalize = datetime.now()

print('time to normalize data:', finish_normalize - finish_get_means)
# Out:
# time to concat: 0:00:00.818502
# time to get std&mean from X1: 0:00:01.222609
# time to get std&mean from X2: 0:00:00.389236
# time to get means: 0:00:02.497316
# time to normalize data: 0:00:01.057759

# %% [markdown]
# inspect data
# (commented out because it takes too long to plot so many data points and I'm confident I know what it looks like)

# %%
# fig, (ax0, ax1) = plot_data(train, val, test, node=0)

# plt.tight_layout()
# plt.show()

# %% [markdown]
# ## sandbox

# %% [markdown]
# ### 3-layer GCN

# %% [markdown]
# #### train to overfit on single data point

# %%
model, history, fname = make_train_GCN3(train,
                                        val,
                                        activation="relu",
                                        epochs=30,
                                        eval_val=True,
                                        early_stopping=True,
                                        early_stopping_patience=5,
                                        early_stopping_start_from_epoch=10,
                                        tensorboard=True)
# Out:
# Epoch 1/100
# 219/219 [==============================] - 18s 74ms/step - loss: 36.1343 - val_loss: 1.1918
# Epoch 2/100
#  45/219 [=====>........................] - ETA: 11s - loss: 1.1531

# %%
fig_train_loss, fig_train_pred, fig_val_pred = plot_model_results(
    train[:1000], val[:1000], model, history, epochs=5)
# Out:
# 32/32 [==============================] - 1s 21ms/step
# 32/32 [==============================] - 1s 23ms/step

# %% [markdown]
# ok, so even though we added complexity, it's still not learning any variation. maybe we need to train for longer epochs?

# %%
model2, history2, fname2 = make_train_GCN3(train,
                                           val,
                                           activation="relu",
                                           epochs=100,
                                           eval_val=True,
                                           early_stopping=True,
                                           early_stopping_patience=10,
                                           early_stopping_start_from_epoch=50,
                                           tensorboard=True,
                                           verbose=2)
# Out:
# Epoch 1/100
# 219/219 - 15s - loss: 7.8082 - val_loss: 1.1891 - 15s/epoch - 70ms/step
# Epoch 2/100
# 219/219 - 14s - loss: 1.1805 - val_loss: 1.1885 - 14s/epoch - 64ms/step
# Epoch 3/100
# 219/219 - 15s - loss: 1.1773 - val_loss: 1.1879 - 15s/epoch - 66ms/step
# Epoch 4/100
# 219/219 - 15s - loss: 1.1768 - val_loss: 1.1873 - 15s/epoch - 68ms/step
# Epoch 5/100
# 219/219 - 15s - loss: 1.1750 - val_loss: 1.1864 - 15s/epoch - 69ms/step
# Epoch 6/100
# 219/219 - 15s - loss: 1.1735 - val_loss: 1.1855 - 15s/epoch - 67ms/step
# Epoch 7/100
# 219/219 - 15s - loss: 1.1722 - val_loss: 1.1843 - 15s/epoch - 68ms/step
# Epoch 8/100
# 219/219 - 15s - loss: 1.1699 - val_loss: 1.1806 - 15s/epoch - 67ms/step
# Epoch 9/100
# 219/219 - 15s - loss: 1.1657 - val_loss: 1.1763 - 15s/epoch - 66ms/step
# Epoch 10/100
# 219/219 - 17s - loss: 1.1620 - val_loss: 1.1742 - 17s/epoch - 76ms/step
# Epoch 11/100
# 219/219 - 16s - loss: 1.1621 - val_loss: 1.1731 - 16s/epoch - 75ms/step
# Epoch 12/100
# 219/219 - 14s - loss: 1.1582 - val_loss: 1.1710 - 14s/epoch - 65ms/step
# Epoch 13/100
# 219/219 - 14s - loss: 1.1566 - val_loss: 1.1682 - 14s/epoch - 66ms/step
# Epoch 14/100
# 219/219 - 14s - loss: 1.1536 - val_loss: 1.1656 - 14s/epoch - 65ms/step
# Epoch 15/100
# 219/219 - 14s - loss: 1.1510 - val_loss: 1.1626 - 14s/epoch - 65ms/step
# Epoch 16/100
# 219/219 - 14s - loss: 1.1479 - val_loss: 1.1597 - 14s/epoch - 65ms/step
# Epoch 17/100
# 219/219 - 16s - loss: 1.1446 - val_loss: 1.1564 - 16s/epoch - 75ms/step
# Epoch 18/100
# 219/219 - 17s - loss: 1.1415 - val_loss: 1.1528 - 17s/epoch - 79ms/step
# Epoch 19/100
# 219/219 - 16s - loss: 1.1381 - val_loss: 1.1503 - 16s/epoch - 71ms/step
# Epoch 20/100
# 219/219 - 20s - loss: 1.1345 - val_loss: 1.1463 - 20s/epoch - 91ms/step
# Epoch 21/100
# 219/219 - 19s - loss: 1.1301 - val_loss: 1.1423 - 19s/epoch - 85ms/step
# Epoch 22/100
# 219/219 - 17s - loss: 1.1259 - val_loss: 1.1374 - 17s/epoch - 79ms/step
# Epoch 23/100
# 219/219 - 18s - loss: 1.1214 - val_loss: 1.1332 - 18s/epoch - 80ms/step
# Epoch 24/100
# 219/219 - 18s - loss: 1.1165 - val_loss: 1.1282 - 18s/epoch - 81ms/step
# Epoch 25/100
# 219/219 - 22s - loss: 1.1116 - val_loss: 1.1244 - 22s/epoch - 100ms/step
# Epoch 26/100
# 219/219 - 23s - loss: 1.1063 - val_loss: 1.1184 - 23s/epoch - 106ms/step
# Epoch 27/100
# 219/219 - 26s - loss: 1.1007 - val_loss: 1.1127 - 26s/epoch - 117ms/step
# Epoch 28/100
# 219/219 - 26s - loss: 1.0958 - val_loss: 1.1085 - 26s/epoch - 119ms/step
# Epoch 29/100
# 219/219 - 26s - loss: 1.0904 - val_loss: 1.1039 - 26s/epoch - 117ms/step
# Epoch 30/100
# 219/219 - 26s - loss: 1.0855 - val_loss: 1.0972 - 26s/epoch - 117ms/step
# Epoch 31/100
# 219/219 - 690s - loss: 1.0795 - val_loss: 1.0909 - 690s/epoch - 3s/step
# Epoch 32/100
# 219/219 - 23s - loss: 1.0735 - val_loss: 1.0871 - 23s/epoch - 106ms/step
# Epoch 33/100
# 219/219 - 23s - loss: 1.0676 - val_loss: 1.0828 - 23s/epoch - 104ms/step
# Epoch 34/100
# 219/219 - 24s - loss: 1.0620 - val_loss: 1.0758 - 24s/epoch - 111ms/step
# Epoch 35/100
# 219/219 - 23s - loss: 1.0559 - val_loss: 1.0691 - 23s/epoch - 104ms/step
# Epoch 36/100
# 219/219 - 22s - loss: 1.0503 - val_loss: 1.0662 - 22s/epoch - 102ms/step
# Epoch 37/100
# 219/219 - 19s - loss: 1.0490 - val_loss: 1.0697 - 19s/epoch - 86ms/step
# Epoch 38/100
# 219/219 - 19s - loss: 1.0497 - val_loss: 1.0555 - 19s/epoch - 85ms/step
# Epoch 39/100
# 219/219 - 19s - loss: 1.0393 - val_loss: 1.0530 - 19s/epoch - 85ms/step
# Epoch 40/100
# 219/219 - 19s - loss: 1.0343 - val_loss: 1.0489 - 19s/epoch - 89ms/step
# Epoch 41/100
# 219/219 - 19s - loss: 1.0291 - val_loss: 1.0421 - 19s/epoch - 87ms/step
# Epoch 42/100
# 219/219 - 19s - loss: 1.0231 - val_loss: 1.0368 - 19s/epoch - 85ms/step
# Epoch 43/100
# 219/219 - 19s - loss: 1.0193 - val_loss: 1.0325 - 19s/epoch - 87ms/step
# Epoch 44/100
# 219/219 - 18s - loss: 1.0420 - val_loss: 1.1023 - 18s/epoch - 84ms/step
# Epoch 45/100
# 219/219 - 18s - loss: 1.0819 - val_loss: 1.0863 - 18s/epoch - 84ms/step
# Epoch 46/100
# 219/219 - 19s - loss: 1.0682 - val_loss: 1.0742 - 19s/epoch - 86ms/step
# Epoch 47/100
# 219/219 - 19s - loss: 1.0560 - val_loss: 1.0627 - 19s/epoch - 85ms/step
# Epoch 48/100
# 219/219 - 19s - loss: 1.0455 - val_loss: 1.0532 - 19s/epoch - 86ms/step
# Epoch 49/100
# 219/219 - 19s - loss: 1.0384 - val_loss: 1.0474 - 19s/epoch - 85ms/step
# Epoch 50/100
# 219/219 - 19s - loss: 1.0311 - val_loss: 1.0398 - 19s/epoch - 86ms/step
# Epoch 51/100
# 219/219 - 18s - loss: 1.0244 - val_loss: 1.0338 - 18s/epoch - 84ms/step
# Epoch 52/100
# 219/219 - 19s - loss: 1.0382 - val_loss: 1.0890 - 19s/epoch - 88ms/step
# Epoch 53/100
# 219/219 - 19s - loss: 1.0671 - val_loss: 1.0695 - 19s/epoch - 89ms/step
# Epoch 54/100
# 219/219 - 19s - loss: 1.0494 - val_loss: 1.0545 - 19s/epoch - 85ms/step
# Epoch 55/100
# 219/219 - 19s - loss: 1.0364 - val_loss: 1.0434 - 19s/epoch - 85ms/step
# Epoch 56/100
# 219/219 - 19s - loss: 1.0264 - val_loss: 1.0344 - 19s/epoch - 86ms/step
# Epoch 57/100
# 219/219 - 21s - loss: 1.0185 - val_loss: 1.0275 - 21s/epoch - 95ms/step
# Epoch 58/100
# 219/219 - 19s - loss: 1.0124 - val_loss: 1.0221 - 19s/epoch - 86ms/step
# Epoch 59/100
# 219/219 - 19s - loss: 1.0077 - val_loss: 1.0180 - 19s/epoch - 86ms/step
# Epoch 60/100
# 219/219 - 19s - loss: 1.0040 - val_loss: 1.0149 - 19s/epoch - 86ms/step
# Epoch 61/100
# 219/219 - 19s - loss: 1.0098 - val_loss: 1.0199 - 19s/epoch - 85ms/step
# Epoch 62/100
# 219/219 - 20s - loss: 1.0041 - val_loss: 1.0137 - 20s/epoch - 90ms/step
# Epoch 63/100
# 219/219 - 19s - loss: 1.0002 - val_loss: 1.0143 - 19s/epoch - 86ms/step
# Epoch 64/100
# 219/219 - 19s - loss: 0.9995 - val_loss: 1.0105 - 19s/epoch - 86ms/step
# Epoch 65/100
# 219/219 - 19s - loss: 0.9963 - val_loss: 1.0072 - 19s/epoch - 87ms/step
# Epoch 66/100
# 219/219 - 19s - loss: 1.0112 - val_loss: 1.0328 - 19s/epoch - 85ms/step
# Epoch 67/100
# 219/219 - 19s - loss: 1.0111 - val_loss: 1.0166 - 19s/epoch - 89ms/step
# Epoch 68/100
# 219/219 - 19s - loss: 1.0091 - val_loss: 1.0155 - 19s/epoch - 88ms/step
# Epoch 69/100
# 219/219 - 19s - loss: 0.9993 - val_loss: 1.0090 - 19s/epoch - 85ms/step
# Epoch 70/100
# 219/219 - 19s - loss: 0.9952 - val_loss: 1.0068 - 19s/epoch - 85ms/step
# Epoch 71/100
# 219/219 - 18s - loss: 0.9932 - val_loss: 1.0046 - 18s/epoch - 84ms/step
# Epoch 72/100
# 219/219 - 19s - loss: 0.9986 - val_loss: 1.0179 - 19s/epoch - 88ms/step
# Epoch 73/100
# 219/219 - 19s - loss: 0.9988 - val_loss: 1.0110 - 19s/epoch - 87ms/step
# Epoch 74/100
# 219/219 - 19s - loss: 1.0027 - val_loss: 1.0083 - 19s/epoch - 87ms/step
# Epoch 75/100
# 219/219 - 19s - loss: 0.9935 - val_loss: 1.0042 - 19s/epoch - 89ms/step
# Epoch 76/100
# 219/219 - 19s - loss: 0.9915 - val_loss: 1.0030 - 19s/epoch - 88ms/step
# Epoch 77/100
# 219/219 - 19s - loss: 0.9952 - val_loss: 1.0147 - 19s/epoch - 85ms/step
# Epoch 78/100
# 219/219 - 22s - loss: 1.0029 - val_loss: 1.0116 - 22s/epoch - 101ms/step
# Epoch 79/100
# 219/219 - 20s - loss: 0.9956 - val_loss: 1.0057 - 20s/epoch - 91ms/step
# Epoch 80/100
# 219/219 - 20s - loss: 0.9923 - val_loss: 1.0042 - 20s/epoch - 90ms/step
# Epoch 81/100
# 219/219 - 18s - loss: 0.9910 - val_loss: 1.0028 - 18s/epoch - 82ms/step
# Epoch 82/100
# 219/219 - 17s - loss: 0.9940 - val_loss: 1.0029 - 17s/epoch - 80ms/step
# Epoch 83/100
# 219/219 - 17s - loss: 0.9926 - val_loss: 1.0077 - 17s/epoch - 79ms/step
# Epoch 84/100
# 219/219 - 18s - loss: 0.9918 - val_loss: 1.0027 - 18s/epoch - 80ms/step
# Epoch 85/100
# 219/219 - 18s - loss: 0.9899 - val_loss: 1.0019 - 18s/epoch - 83ms/step
# Epoch 86/100
# 219/219 - 20s - loss: 0.9946 - val_loss: 1.0033 - 20s/epoch - 93ms/step
# Epoch 87/100
# 219/219 - 19s - loss: 0.9899 - val_loss: 1.0017 - 19s/epoch - 85ms/step
# Epoch 88/100
# 219/219 - 17s - loss: 0.9892 - val_loss: 1.0014 - 17s/epoch - 78ms/step
# Epoch 89/100
# 219/219 - 17s - loss: 0.9890 - val_loss: 1.0012 - 17s/epoch - 78ms/step
# Epoch 90/100
# 219/219 - 17s - loss: 0.9985 - val_loss: 1.0826 - 17s/epoch - 79ms/step
# Epoch 91/100
# 219/219 - 17s - loss: 1.0282 - val_loss: 1.0181 - 17s/epoch - 79ms/step
# Epoch 92/100
# 219/219 - 17s - loss: 0.9987 - val_loss: 1.0063 - 17s/epoch - 78ms/step
# Epoch 93/100
# 219/219 - 17s - loss: 0.9953 - val_loss: 1.0040 - 17s/epoch - 78ms/step
# Epoch 94/100
# 219/219 - 17s - loss: 0.9900 - val_loss: 1.0015 - 17s/epoch - 79ms/step
# Epoch 95/100
# 219/219 - 17s - loss: 0.9904 - val_loss: 1.0022 - 17s/epoch - 78ms/step
# Epoch 96/100
# 219/219 - 17s - loss: 0.9889 - val_loss: 1.0009 - 17s/epoch - 78ms/step
# Epoch 97/100
# 219/219 - 18s - loss: 0.9891 - val_loss: 1.0008 - 18s/epoch - 80ms/step
# Epoch 98/100
# 219/219 - 18s - loss: 0.9923 - val_loss: 1.0386 - 18s/epoch - 83ms/step
# Epoch 99/100
# 219/219 - 18s - loss: 0.9981 - val_loss: 1.0022 - 18s/epoch - 81ms/step
# Epoch 100/100
# 219/219 - 18s - loss: 0.9890 - val_loss: 1.0009 - 18s/epoch - 81ms/step

# %%
fig_train_loss, fig_train_pred, fig_val_pred = plot_model_results(
    train[:1000], val[:1000], model2, history2, model_name='GCN', epochs=100)
# Out:
# 32/32 [==============================] - 1s 28ms/step
# 32/32 [==============================] - 1s 21ms/step
